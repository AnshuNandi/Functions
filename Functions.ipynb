# %% [markdown]
# # Theory Questions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# Answer:
#
# - A function in Python is a block of reusable code defined independently using the def keyword or lambda. It can be called directly without being tied to an object.
# - A method is also a function but it is defined inside a class and is associated with an object. It often operates on the object’s data.

# %%
#Example
def add(a, b):
    return a + b   # Function

class Test:
    def show(self):
        return "Hello"   # Method

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
# Answer:
#
# - Parameter: Variable in the function definition.
#
# - Argument: Actual value passed during function call.

# %%
#example
def greet(name):  # 'name' is parameter
    return "Hello " + name

print(greet("Anshu"))  # "Anshu" is argument
# Out:
# Hello Anshu

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
# Answer:

# %%
# 1. Simple Function

def f1():
  return "Hi"
print(f1())
# Out:
# Hi

# %%
# 2. Function with Parameters

def f2(a, b):
  return a+b
print(f2(2,3))
# Out:
# 5

# %%
# 3. Lambda Function

f3 = lambda x: x*x
print(f3(4))
# Out:
# 16

# %% [markdown]
# 4. What is the purpose of the return statement in a Python function?
#
# Answer:
#
# The return statement exits the function and sends a value back to the caller. Without return, the function gives None.

# %%
#example
def add(a,b):
  return a+b
print(add(5,7))
# Out:
# 12

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
# Answer:
#
# - Iterable: Any object we can loop over (list, tuple, str).
#
# - Iterator: An object that produces values one at a time using __next__().

# %%
#Example
nums = [10, 20, 30]   # iterable
it = iter(nums)       # creates an iterator from the list
print(next(it))
print(next(it))
print(next(it))
# Out:
# 10
# 20
# 30

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#
# Answer: A generator is a special function that uses yield to produce values one at a time. It does not store all values in memory.

# %%
#Example
def g():
    for i in range(3): yield i
for x in g(): print(x)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# Answer:
#
# - More memory efficient (no need to store large data structures).
#
# - Support lazy evaluation (values generated only when needed).
#
# - Can represent infinite sequences.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
# Answer:
# A lambda function is a small, anonymous, one-line function.
# It is often used where short-lived functions are needed (e.g., sorting, mapping, filtering).

# %%
#Example
f=lambda a,b:a+b
print(f(3,4))
# Out:
# 7

# %% [markdown]
# 9. Explain the purpose and usage of the map() function in Python.
#
# Answer:
# The map() function applies a given function to each element of an iterable and returns a new iterable (map object).

# %%
#Example:
lst=[1,2,3]
print(list(map(lambda x:x*2,lst)))
# Out:
# [2, 4, 6]

# %% [markdown]
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#
# Answer:
#
# - map(): Applies a function to all items of an iterable.
#
# - filter(): Keeps items that satisfy a condition.
#
# - reduce(): Repeatedly applies a function to pairs of items, reducing iterable to a single value.

# %%
#Example:
from functools import reduce
lst=[1,2,3,4]
print(list(map(lambda x:x*2,lst)))    # [2,4,6,8]
print(list(filter(lambda x:x%2==0,lst))) # [2,4]
print(reduce(lambda a,b:a+b,lst))  # 10
# Out:
# [2, 4, 6, 8]
# [2, 4]
# 10

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using reduce function on this given list: [47,11,42,13]
#
# Answer:

# %% [markdown]
# ![WhatsApp Image 2025-10-03 at 22.22.41_c94c84ac.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Practical Questions

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def s(lst):
    return sum([x for x in lst if x%2==0])

print(s([1,2,3,4,5,6]))
# Out:
# 12

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.
def r(s): return s[::-1]

print(r("python"))
# Out:
# nohtyp

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def sq(lst): return [x*x for x in lst]

print(sq([1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def p(n):
    if n<2:return 0
    for i in range(2,int(n**0.5)+1):
        if n%i==0:return 0
    return 1

print([i for i in range(1,21) if p(i)])
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
class F:
    def __init__(s,n):s.n=n;s.a=0;s.b=1;s.i=0
    def __iter__(s):return s
    def __next__(s):
        if s.i>=s.n:raise StopIteration
        if s.i==0:r=0
        elif s.i==1:r=1
        else:r=s.a+s.b;s.a,s.b=s.b,r
        s.i+=1
        return r

print(list(F(7)))
# Out:
# [0, 1, 1, 2, 3, 5, 8]

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def g(n):
    for i in range(n+1):yield 2**i

print(list(g(5)))
# Out:
# [1, 2, 4, 8, 16, 32]

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.
from google.colab import files
uploaded = files.upload()
filename = list(uploaded.keys())[0]

def g(f):
    with open(f) as fp:
        for l in fp:
            yield l.strip()

for line in g(filename):
    print(line)
# Out:
#      <input type="file" id="files-fed6f09b-1ad8-400b-b7be-45ce79164b71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fed6f09b-1ad8-400b-b7be-45ce79164b71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
lst=[(1,3),(2,1),(5,2)]
lst.sort(key=lambda x:x[1])
print(lst)
# Out:
# [(2, 1), (5, 2), (1, 3)]

# %%
# 9. Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit.
c=[0,20,30,100]
f=list(map(lambda x:(x*9/5)+32,c))
print(f)
# Out:
# [32.0, 68.0, 86.0, 212.0]

# %%
# 10. Create a Python program that uses filter() to remove all the vowels from a given string.
s="hello world"
r="".join(filter(lambda x:x not in"aeiouAEIOU",s))
print(r)
# Out:
# hll wrld

# %% [markdown]
# ![Screenshot 2025-10-03 222837.png](data:image/png;base64,...)

# %%
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:(above pic)
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €. Write a Python program using lambda and map.

o=[[34587,"Learning Python, Mark Lutz",4,40.95],
   [98762,"Programming Python, Mark Lutz",5,56.80],
   [77226,"Head First Python, Paul Barry",3,32.95],
   [88112,"Einführung in Python3, Bernd Klein",3,24.99]]

r=list(map(lambda x:(x[0],x[2]*x[3] if x[2]*x[3]>=100 else x[2]*x[3]+10),o))
print(r)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
